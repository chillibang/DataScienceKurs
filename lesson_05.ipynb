# %%
# Zadanie 5

csv = "Alice, 28, Data Science, 75000"

lines = csv.split(', ')

print(f"Name: {lines[0]}\n"
      f"Age: {lines[1]}\n"
      f"Profession: {lines[2]}\n"
      f"Salary: {lines[3]}\n"
      )
# Out:
# Name: Alice
# Age: 28
# Profession: Data Science
# Salary: 75000

# %%
# Zadanie 8

file_name = "model_results_2024_Q3.csv"

file_name_only = file_name.split('.')

file_name_parts = file_name_only[0].split('_')

print(f"Year: {file_name_parts[2]}\n"
      f"Quarter: {file_name_parts[3]}\n"
      )
# Out:
# Year: 2024
# Quarter: Q3

# %%
# Zadanie 9

measurements = [23, 24, 22, 150, 23, 25, -10, 24, 23]

outliers = [20, 30]
filtered_measurements = []

for m in measurements:
    if m > 20 and m < 30:
        filtered_measurements.append(m)


# filtered_measurements = [m for m in measurements if m not in outliers]
print(f"Filtered measurements: {filtered_measurements}")
# Out:
# Filtered measurements: [23, 24, 22, 23, 25, 24, 23]

# %%
# Zadanie 10 
 
transactions = [
    ('food', 50),
    ('transport', 20),
    ('food', 30),
    ('entertainment', 40),
    ('transport', 15),
    ('food', 25)
]

total = {}

for category, value in transactions:
    if category in total:
        total[category] += value
    else:
        total[category] = value

print(total)
# Out:
# {'food': 105, 'transport': 35, 'entertainment': 40}
