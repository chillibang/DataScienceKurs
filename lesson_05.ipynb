# %%
# Zadanie 5

csv = "Alice, 28, Data Science, 75000"

lines = csv.split(', ')

print(f"Name: {lines[0]}\n"
      f"Age: {lines[1]}\n"
      f"Profession: {lines[2]}\n"
      f"Salary: {lines[3]}\n"
      )
# Out:
# Name: Alice
# Age: 28
# Profession: Data Science
# Salary: 75000
